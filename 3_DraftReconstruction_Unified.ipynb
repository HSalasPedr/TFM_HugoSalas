# %% [markdown]
# # Notebook 1: Homology matrix generation from genome sequences
#
# Generate strain-specific model for PmegMOA
#
# 1. Perform BLASTp to find homologous proteins in strains of interest
# 2. Use best bidirectional hits to create gene presence/absence matrix
# 3. Supplementary for best practice: use BLASTn to check if we have missed any unannotated open reading frames and retain these genes in orthology matrix as well as guide future manual curation

# %%
#import packages needed
import pandas as pd
from glob import glob
from Bio import Entrez, SeqIO

# %% [markdown]
# ### Generate FASTA files for both Protein and Nucleotide Pipelines
# From the GenBank file, we can extract sequence and annoation information to generate fasta files for the protein and nucleotide analyses. The resulting fasta files will then be used in step 2 as input for BLAST

# %%
referenceStrainID = 'DSM319'
targetStrainID = 'PmegMOA'

# %%
# define a function to parse the Genbank file to generate fasta files for both protein and nucleotide sequences
def parse_genome(id, type = 'prot', in_folder = 'genomes', out_folder = 'prots', overwrite = 1):

    in_file = '%s/%s.gb'%(in_folder, id)
    out_file = '%s/%s.fa'%(out_folder, id)
    files = glob('%s/*.fa'%out_folder)
    
    if out_file in files and overwrite == 0:
        print (out_file, 'already parsed')
        return
    else:
        print ('parsing %s'%id)
    
    handle = open(in_file)
    
    fout = open(out_file, 'w')
    x = 0
    
    records = SeqIO.parse(handle, "genbank")
    for record in records:
        for f in record.features:
            if f.type == 'CDS':
                seq = f.extract(record.seq)
                
                if type == 'nucl':
                    seq = str(seq)
                else:
                    seq = str(seq.translate())
                    
                if 'locus_tag' in f.qualifiers.keys():
                    locus = f.qualifiers['locus_tag'][0]
                elif 'gene' in f.qualifiers.keys():
                    locus = f.qualifiers['gene'][0]
                else:
                    locus = 'gene_%i'%x
                    x += 1
                fout.write('>%s\n%s\n'%(locus, seq))
    fout.close()

# %%
# Generate fasta files for PmegMOA

parse_genome(targetStrainID, type = 'prot', in_folder = 'genomes', out_folder = 'prots')
parse_genome(targetStrainID, type = 'nucl', in_folder = 'genomes', out_folder = 'nucl')
# Out:
# parsing PmegMOA
# parsing PmegMOA

# %%
#Also generate fasta files for the reference strain

parse_genome(referenceStrainID, type = 'nucl', in_folder = 'genomes', out_folder = 'nucl')
parse_genome(referenceStrainID, type = 'prots', in_folder = 'genomes', out_folder = 'prots')
# Out:
# parsing DSM319
# parsing DSM319

# %% [markdown]
# ## 1. Perform BLAST to find homologous proteins in strains of interest

# %% [markdown]
# Make BLAST DB for each of the target strains for both Protein and Nucleotide Pipelines
#
# In this tutorial, we will run both BLASTp for proteins and BLASTn for nucleotides. BLASTp will be used as the main approach to identify homologous proteins in reference strain and other strains of interest, while BLASTn will be used as a supplementary method to check for any unannotated genes

# %%
# Define a function to make blast database for either protein of nucleotide
def make_blast_db(id, folder = 'prots', db_type = 'prot'):
    import os
    
    out_file = '%s/%s.fa.pin'%(folder, id)
    files = glob('%s/*.fa.pin'%folder)
    
    if out_file in files:
        print (id, 'already has a blast db')
        return
    if db_type == 'nucl':
        ext = 'fna'
    else:
        ext = 'fa'

    cmd_line = 'makeblastdb -in %s/%s.%s -dbtype %s' %(folder, id, ext, db_type)
    
    print ('making blast db with following command line...')
    print (cmd_line)
    os.system(cmd_line)

# %%
make_blast_db(targetStrainID, folder = 'prots', db_type = 'prot')
make_blast_db(referenceStrainID, folder = 'prots', db_type = 'prot')
# Out:
# PmegMOA already has a blast db
# DSM319 already has a blast db

# %% [markdown]
# ### Define functions to run protein BLAST and get sequence lengths
# - BLASTp will be the main approach used here to identify homologous proteins between strains
# - Aside from sequence similarity, we also want to ensure the coverage of sequence mapping is sufficient. Therefore, we need to identiy the sequence length for each protein and compare it with the alignment length.

# %%
# define a function to run BLASTp
def run_blastp(seq, db, in_folder = 'prots', out_folder = 'bbh', out = None, outfmt = 6, evalue = 0.001, threads = 1):
    import os
    if out == None:
        out = '%s/%s_vs_%s.txt'%(out_folder, seq, db)
        print(out)
    
    files = glob('%s/*.txt'%out_folder)
    if out in files:
        print (seq, 'already blasted')
        return
    
    print('blasting %s vs %s'%(seq, db))
    
    db = '%s/%s.fa'%(in_folder, db)
    seq = '%s/%s.fa'%(in_folder, seq)
    cmd_line = 'blastp -db %s -query %s -out %s -evalue %s -outfmt %s -num_threads %i' \
    %(db, seq, out, evalue, outfmt, threads)
    
    print ('running blastp with following command line...')
    print (cmd_line)
    os.system(cmd_line)
    return out

# %%
# define a function to get sequence length 

def get_gene_lens(query, in_folder = 'prots'):

    file = '%s/%s.fa'%(in_folder, query)
    handle = open(file)
    records = SeqIO.parse(handle, "fasta")
    out = []
    
    for record in records:
        out.append({'gene':record.name, 'gene_length':len(record.seq)})
    
    out = pd.DataFrame(out)
    return out

# %% [markdown]
# ## 2. Use Bi-Directional BLASTp Best Hits to create gene presence/absence matrix

# %% [markdown]
# ### Obtain Bi-Directional BLASTp Best Hits
#
# From the above BLASTp results, we can obtain Bi-Directional BLASTp Best Hits to identify homologous proteins. Note beside gene similarity score, the coverage of alignment is also used to filter mapping results.

# %%
# define a function to get Bi-Directional BLASTp Best Hits
def get_bbh(query, subject, in_folder = 'bbh'):    
    
    #Utilize the defined protein BLAST function
    run_blastp(query, subject)
    run_blastp(subject, query)
    
    query_lengths = get_gene_lens(query, in_folder = 'prots')
    subject_lengths = get_gene_lens(subject, in_folder = 'prots')
    
    #Define the output file of this BLAST
    out_file = '%s/%s_vs_%s_parsed.csv'%(in_folder,query, subject)
    files = glob('%s/*_parsed.csv'%in_folder)
    
    #Combine the results of the protein BLAST into a dataframe
    print ('parsing BBHs for', query, subject)
    cols = ['gene', 'subject', 'PID', 'alnLength', 'mismatchCount', 'gapOpenCount', 'queryStart', 'queryEnd', 'subjectStart', 'subjectEnd', 'eVal', 'bitScore']
    bbh = pd.read_csv('%s/%s_vs_%s.txt'%(in_folder, query, subject), sep = '\t', names = cols)
    bbh = pd.merge(bbh, query_lengths) 
    bbh['COV'] = bbh['alnLength']/bbh['gene_length']
    
    bbh2 = pd.read_csv('%s/%s_vs_%s.txt'%(in_folder, subject, query), sep = '\t', names = cols)
    bbh2 = pd.merge(bbh2, subject_lengths) 
    bbh2['COV'] = bbh2['alnLength']/bbh2['gene_length']
    out = pd.DataFrame()
    
    # Filter the genes based on coverage
    bbh = bbh[bbh.COV >= 0.25]
    bbh2 = bbh2[bbh2.COV >= 0.25]
    
    #Delineate the best hits from the BLAST
    for g in bbh.gene.unique():
        res = bbh[bbh.gene == g]
        if len(res) == 0:
            continue
        best_hit = res.loc[res.PID.idxmax()]
        best_gene = best_hit.subject
        res2 = bbh2[bbh2.gene == best_gene]
        if len(res2) == 0:
            continue
        best_hit2 = res2.loc[res2.PID.idxmax()]
        best_gene2 = best_hit2.subject
        if g == best_gene2:
            best_hit['BBH'] = '<=>'
        else:
            best_hit['BBH'] = '->'
        out = pd.concat([out, pd.DataFrame(best_hit).transpose()])
    
    #Save the final file to a designated CSV file    
    out.to_csv(out_file)

# %%
# Execute the BLAST for each target strain against the reference strain, save results to 'bbh' i.e. "bidirectional best
# hits" folder to create homology matrix

get_bbh(referenceStrainID, targetStrainID, in_folder = 'bbh')
# Out:
# bbh/DSM319_vs_PmegMOA.txt
# DSM319 already blasted
# bbh/PmegMOA_vs_DSM319.txt
# PmegMOA already blasted
# parsing BBHs for DSM319 PmegMOA
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# ...
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /tmp/ipykernel_5719/1865688047.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'

# %% [markdown]
# ### Parse the BLAST Results into one Homology Matrix of the Reconstruction Genes
#
# For the homology matrix, we only focus on genes that are present in the reference model

# %%
#Load all the BLAST files between the reference strain and target strains

blast_files = glob('%s/*_parsed.csv'%'bbh')

for blast in blast_files:
    bbh = pd.read_csv(blast)
    print(blast, bbh.shape)
# Out:
# bbh/DSM319_vs_PmegMOA_parsed.csv (4142, 16)

# %%
import cobra
model = cobra.io.read_sbml_model('DSM319_fixedIDs.xml')
listGeneIDs = []

for gene in model.genes:
    listGeneIDs.append(gene.id)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-12-18

# %%
listGeneIDs
# Out:
# ['BMD_RS23170',
#  'BMD_RS25275',
#  'BMD_RS08645',
#  'BMD_RS15095',
#  'BMD_RS03235',
#  'BMD_1109',
#  'BMD_RS15100',
#  'BMD_RS18115',
#  'BMD_RS21035',
#  'BMD_RS06730',
#  'BMD_RS22490',
#  'BMD_RS11860',
#  'BMD_RS04675',
#  'BMD_RS05260',
#  'BMD_RS11340',
#  'BMD_RS19665',
#  'BMD_RS06970',
#  'BMD_RS19655',
#  'BMD_RS11715',
#  'BMD_RS21045',
#  'BMD_RS09975',
#  'BMD_RS09980',
#  'BMD_RS06670',
#  'BMD_RS17340',
#  'BMD_RS17350',
#  'BMD_RS08250',
#  'BMD_RS19775',
#  'BMD_RS03985',
#  'BMD_RS03355',
#  'BMD_RS03360',
#  'BMD_RS20550',
#  'BMD_RS20555',
#  'BMD_RS10140',
#  'BMD_RS19970',
#  'BMD_RS22865',
#  'BMD_RS19975',
#  'BMD_RS24100',
#  'BMD_RS19620',
#  'BMD_RS24090',
#  'BMD_RS16545',
#  'BMD_RS24095',
#  'BMD_RS19565',
#  'BMD_RS11580',
#  'BMD_RS21100',
#  'BMD_RS02900',
#  'BMD_RS01125',
#  'BMD_RS01145',
#  'BMD_RS07425',
#  'BMD_RS20410',
#  'BMD_RS22795',
#  ...]

# %%
#Create 2 matrices of N, rows where N is the number of model genes and M columns where M is the number of target strains
#One matrix will be populated with the PID results from the blasts and another with the mapping of gene locus tags

ortho_matrix = pd.DataFrame(index = listGeneIDs, columns = [targetStrainID])
geneIDs_matrix = pd.DataFrame(index = listGeneIDs, columns = [targetStrainID])

# %%
#Parse through each blast file and acquire pertinent information for each matrix for each of the base reconstruction genes
for blast in blast_files:
    bbh = pd.read_csv(blast)
    listIDs = []
    listPID = []
    for r, row in ortho_matrix.iterrows():
        try:
            currentOrtholog = bbh[bbh['gene'] == r].reset_index()
            listIDs.append(currentOrtholog.iloc[0]['subject'])
            listPID.append(currentOrtholog.iloc[0]['PID'])
        except:
            listIDs.append('None')
            listPID.append(0)
    for col in ortho_matrix.columns:
        if col in blast:
            ortho_matrix[col] = listPID
            geneIDs_matrix[col] = listIDs

# %% [markdown]
# ### Apply Similarity Threshold to Binarize  Homology Matrix to Presence/Absence Matrix
# In this step, choose a threshold for the PID to determine if a gene is a absent/present in the strain of interest. We can then convert the homology matrix generated above into a binarized presence/absence matrix

# %%
# Genes with a greater than 80% PID are considered present in the target strain genome 
# and consequently less than 80% are considered absent from the target strain genome
for column in ortho_matrix:
    ortho_matrix.loc[ortho_matrix[column] <= 80.0,column] = 0
    ortho_matrix.loc[ortho_matrix[column] > 80.0,column] = 1

# %%
ortho_matrix
# Out:
#              PmegMOA
# BMD_RS23170      1.0
# BMD_RS25275      1.0
# BMD_RS08645      1.0
# BMD_RS15095      1.0
# BMD_RS03235      1.0
# ...              ...
# BMD_RS06270      1.0
# BMD_RS17410      0.0
# BMD_RS05375      0.0
# BMD_RS05380      0.0
# BMD_RS04495      0.0
#
# [1121 rows x 1 columns]

# %% [markdown]
# ## 3. Perform BLASTn to check unannotated open reading frames to guide manual curation
# At this juncture it may be useful to execute a supplementary nucleotide BLAST to check for unannotated genes, results here become candidates for manual curation. In this tutorial we retain unannotated genes that pass the threhsold for
# similarity and contain no premature stop codons

# %%
#Define a function to generate FNA from the GBK files

def gbk2fasta(gbk_filename):
    faa_filename = '.'.join(gbk_filename.split('.')[:-1])+'.fna'
    input_handle  = open(gbk_filename, "r")
    output_handle = open(faa_filename, "w")

    for seq_record in SeqIO.parse(input_handle, "genbank") :
        print ("Converting GenBank record %s" % seq_record.id)
        output_handle.write(">%s %s\n%s\n" % (
               seq_record.id,
               seq_record.description,
               seq_record.seq))

    output_handle.close()
    input_handle.close()

# %%
#Define function to run the BLASTn

def run_blastn(seq, db, outfmt = 6, evalue = 0.001,threads = 1):
    import os
    out = 'nucl/'+seq+'_vs_'+db+'.txt'
    seq = 'nucl/'+seq+'.fa'
    db = 'genomes/'+db+'.fna'
    
    cmd_line = 'blastn -db %s -query %s -out %s -evalue %s -outfmt %s -num_threads %i' \
    %(db, seq, out, evalue, outfmt, threads)
    
    print ('running blastn with following command line...')
    print (cmd_line)
    os.system(cmd_line)
    return out

# %%
# convert genbank files to fna files for strains of interest

gbk2fasta('genomes/'+targetStrainID+'.gb')
# Converting GenBank record NODE_165_length_4931_cov_129.138237
# Converting GenBank record NODE_166_length_4863_cov_126.957794
# Converting GenBank record NODE_167_length_4857_cov_121.938494
# Converting GenBank record NODE_168_length_4844_cov_121.521712
# Converting GenBank record NODE_169_length_4739_cov_129.598456
# Converting GenBank record NODE_170_length_4595_cov_138.665339
# Converting GenBank record NODE_171_length_4237_cov_132.814423
# Converting GenBank record NODE_172_length_4178_cov_121.686418
# Converting GenBank record NODE_173_length_4118_cov_125.416234
# Converting GenBank record NODE_174_length_4080_cov_164.781414
# Converting GenBank record NODE_175_length_3903_cov_103.819394
# Converting GenBank record NODE_176_length_3890_cov_294.990821
# Converting GenBank record NODE_177_length_3789_cov_120.522360
# Converting GenBank record NODE_178_length_3767_cov_120.926287
# Converting GenBank record NODE_179_length_3686_cov_119.947077
# Converting GenBank record NODE_180_length_3646_cov_130.285794
# Converting GenBank record NODE_181_length_3515_cov_135.301338
# Converting GenBank record NODE_182_length_3473_cov_137.970259
# Converting GenBank record NODE_183_length_3333_cov_120.981265
# Converting GenBank record NODE_184_length_3279_cov_140.228919
# Converting GenBank record NODE_185_length_3184_cov_152.638880
# Converting GenBank record NODE_186_length_3155_cov_159.962963
# Converting GenBank record NODE_187_length_3144_cov_142.803065
# Converting GenBank record NODE_188_length_3142_cov_1701.247961
# Converting GenBank record NODE_189_length_3104_cov_150.186323
# Converting GenBank record NODE_190_length_3079_cov_321.2665
# Converting GenBank record NODE_191_length_2908_cov_84.558813
# Converting GenBank record NODE_192_length_2892_cov_88.589698
# Converting GenBank record NODE_193_length_2597_cov_417.854762
# Converting GenBank record NODE_194_length_2271_cov_145.430720
# Converting GenBank record NODE_195_length_2262_cov_139.808238
# Converting GenBank record NODE_196_length_2224_cov_148.466232
# Converting GenBank record NODE_197_length_2170_cov_103.64501
# Converting GenBank record NODE_198_length_2104_cov_122.306364
# Converting GenBank record NODE_199_length_1927_cov_153.858919
# Converting GenBank record NODE_200_length_1897_cov_121.272527
# Converting GenBank record NODE_201_length_1858_cov_585.709152
# Converting GenBank record NODE_202_length_1838_cov_2365.211811
# Converting GenBank record NODE_203_length_1823_cov_957.719931
# Converting GenBank record NODE_204_length_1750_cov_365.293485
# Converting GenBank record NODE_205_length_1685_cov_821.274254
# Converting GenBank record NODE_206_length_1675_cov_107.943054
# Converting GenBank record NODE_207_length_1636_cov_1855.695318
# Converting GenBank record NODE_208_length_1626_cov_108.50355
# Converting GenBank record NODE_209_length_1604_cov_296.561231
# Converting GenBank record NODE_210_length_1551_cov_1301.119403
# Converting GenBank record NODE_211_length_1524_cov_492.621977
# Converting GenBank record NODE_212_length_1511_cov_122.985356
# Converting GenBank record NODE_213_length_1493_cov_99.652542
# Converting GenBank record NODE_214_length_1488_cov_149.532247
# Converting GenBank record NODE_215_length_1485_cov_149.973722
# Converting GenBank record NODE_216_length_1483_cov_389.800142
# Converting GenBank record NODE_217_length_1448_cov_122.850474
# Converting GenBank record NODE_218_length_1408_cov_519.298272
# Converting GenBank record NODE_219_length_1405_cov_282.481175
# Converting GenBank record NODE_220_length_1401_cov_401.565710
# Converting GenBank record NODE_221_length_1376_cov_2297.192456
# Converting GenBank record NODE_222_length_1354_cov_1267.404072
# Converting GenBank record NODE_223_length_1295_cov_1556.702791
# Converting GenBank record NODE_224_length_1278_cov_97.508743
# Converting GenBank record NODE_225_length_1275_cov_459.876461
# Converting GenBank record NODE_226_length_1265_cov_251.546296
# Converting GenBank record NODE_227_length_1262_cov_581.554430
# Converting GenBank record NODE_228_length_1219_cov_400.354641
# Converting GenBank record NODE_229_length_1127_cov_460.97143
# Converting GenBank record NODE_230_length_1019_cov_1510.723992
# Converting GenBank record NODE_231_length_958_cov_126.175936
# Converting GenBank record NODE_232_length_940_cov_292.190035
# Converting GenBank record NODE_233_length_768_cov_407.599132
# Converting GenBank record NODE_234_length_715_cov_559.233542
# Converting GenBank record NODE_235_length_714_cov_444.221350
# Converting GenBank record NODE_236_length_675_cov_694.48495
# Converting GenBank record NODE_237_length_660_cov_2254.5146
# Converting GenBank record NODE_238_length_641_cov_1668.319149
# Converting GenBank record NODE_239_length_577_cov_362.32000
# Converting GenBank record NODE_240_length_563_cov_1161.864198
# Converting GenBank record NODE_241_length_560_cov_169.921325
# Converting GenBank record NODE_242_length_558_cov_1573.503119
# Converting GenBank record NODE_243_length_547_cov_957.529787
# Converting GenBank record NODE_244_length_543_cov_112.847639
# Converting GenBank record NODE_245_length_518_cov_151.560091
# Converting GenBank record NODE_246_length_481_cov_96.2475
# Converting GenBank record NODE_247_length_427_cov_136.454286
# Converting GenBank record NODE_248_length_411_cov_372.392216
# Converting GenBank record NODE_249_length_355_cov_1351.205036
# Converting GenBank record NODE_250_length_346_cov_273.171004
# Converting GenBank record NODE_251_length_342_cov_113.788679
# Converting GenBank record NODE_252_length_341_cov_160.121212
# Converting GenBank record NODE_253_length_334_cov_1082.552529
# Converting GenBank record NODE_254_length_333_cov_140.894531
# Converting GenBank record NODE_255_length_330_cov_831.624506
# Converting GenBank record NODE_256_length_323_cov_522.727642
# Converting GenBank record NODE_257_length_316_cov_0.439331
# Converting GenBank record NODE_258_length_311_cov_136.880342
# Converting GenBank record NODE_259_length_309_cov_115.112069
# Converting GenBank record NODE_260_length_305_cov_305.166667
# Converting GenBank record NODE_261_length_297_cov_143.872727
# Converting GenBank record NODE_262_length_281_cov_286.813725
# Converting GenBank record NODE_263_length_278_cov_0.721393
# Converting GenBank record NODE_264_length_275_cov_0.717172
# Converting GenBank record NODE_265_length_274_cov_383.299492
# Converting GenBank record NODE_266_length_269_cov_0.770833
# Converting GenBank record NODE_267_length_267_cov_1.73684
# Converting GenBank record NODE_268_length_266_cov_0.783069
# Converting GenBank record NODE_269_length_262_cov_0.702703
# Converting GenBank record NODE_270_length_259_cov_0.813187
# Converting GenBank record NODE_271_length_258_cov_141.756906
# Converting GenBank record NODE_272_length_257_cov_154.877778
# Converting GenBank record NODE_273_length_257_cov_0.688889
# Converting GenBank record NODE_274_length_254_cov_1329.327684
# Converting GenBank record NODE_275_length_250_cov_0.826590
# Converting GenBank record NODE_276_length_250_cov_0.676301
# Converting GenBank record NODE_277_length_249_cov_241.796512
# Converting GenBank record NODE_278_length_248_cov_144.479532
# Converting GenBank record NODE_279_length_247_cov_0.800000
# Converting GenBank record NODE_280_length_246_cov_1.562130
# Converting GenBank record NODE_281_length_245_cov_0.880952
# Converting GenBank record NODE_282_length_245_cov_0.875000
# Converting GenBank record NODE_283_length_244_cov_149.263473
# Converting GenBank record NODE_284_length_244_cov_139.461078
# Converting GenBank record NODE_285_length_244_cov_0.736527
# Converting GenBank record NODE_286_length_243_cov_0.891566
# Converting GenBank record NODE_287_length_243_cov_0.873494
# Converting GenBank record NODE_288_length_242_cov_1.793939
# Converting GenBank record NODE_289_length_239_cov_1.358025
# Converting GenBank record NODE_290_length_239_cov_0.839506
# Converting GenBank record NODE_291_length_238_cov_156.155280
# Converting GenBank record NODE_292_length_238_cov_1.211180
# Converting GenBank record NODE_293_length_238_cov_0.919255
# Converting GenBank record NODE_294_length_237_cov_299.250000
# Converting GenBank record NODE_295_length_237_cov_1.187500
# Converting GenBank record NODE_296_length_237_cov_0.925000
# Converting GenBank record NODE_297_length_236_cov_140.245283
# Converting GenBank record NODE_298_length_236_cov_0.930818
# Converting GenBank record NODE_299_length_236_cov_0.886792
# Converting GenBank record NODE_300_length_235_cov_0.645570
# Converting GenBank record NODE_301_length_234_cov_279.713376
# Converting GenBank record NODE_302_length_234_cov_1.50955
# Converting GenBank record NODE_303_length_234_cov_0.942675
# Converting GenBank record NODE_304_length_234_cov_0.866242
# Converting GenBank record NODE_305_length_233_cov_0.884615
# Converting GenBank record NODE_306_length_233_cov_0.871795
# Converting GenBank record NODE_307_length_233_cov_0.858974
# Converting GenBank record NODE_308_length_233_cov_0.858974
# Converting GenBank record NODE_309_length_232_cov_0.896774
# Converting GenBank record NODE_310_length_232_cov_0.883871
# Converting GenBank record NODE_311_length_232_cov_0.638710
# Converting GenBank record NODE_312_length_231_cov_144.292208
# Converting GenBank record NODE_313_length_230_cov_152.581699
# Converting GenBank record NODE_314_length_230_cov_0.862745
# Converting GenBank record NODE_315_length_229_cov_0.934211
# Converting GenBank record NODE_316_length_220_cov_1006.83916
# Converting GenBank record NODE_317_length_217_cov_276.357143
# Converting GenBank record NODE_318_length_210_cov_529.330827
# Converting GenBank record NODE_319_length_204_cov_128.606299
# Converting GenBank record NODE_320_length_200_cov_148.73171
# Converting GenBank record NODE_321_length_199_cov_300.696721
# Converting GenBank record NODE_322_length_196_cov_1364.126050
# Converting GenBank record NODE_323_length_191_cov_373.228070
# Converting GenBank record NODE_324_length_188_cov_166.315315
# Converting GenBank record NODE_325_length_186_cov_304.293578
# Converting GenBank record NODE_326_length_185_cov_112.101852
# Converting GenBank record NODE_327_length_184_cov_433.327103
# Converting GenBank record NODE_328_length_180_cov_158.514563
# Converting GenBank record NODE_329_length_173_cov_340.62500
# Converting GenBank record NODE_330_length_173_cov_270.312500
# Converting GenBank record NODE_331_length_171_cov_151.627660
# Converting GenBank record NODE_332_length_170_cov_148.387097
# Converting GenBank record NODE_333_length_168_cov_153.791209
# Converting GenBank record NODE_334_length_168_cov_139.593407
# Converting GenBank record NODE_335_length_168_cov_117.439560
# Converting GenBank record NODE_336_length_167_cov_281.344444
# Converting GenBank record NODE_337_length_166_cov_150.887640
# Converting GenBank record NODE_338_length_166_cov_95.730337
# Converting GenBank record NODE_339_length_165_cov_163.738636
# Converting GenBank record NODE_340_length_163_cov_298.34884
# Converting GenBank record NODE_341_length_163_cov_144.790698
# Converting GenBank record NODE_342_length_162_cov_155.352941
# Converting GenBank record NODE_343_length_161_cov_294.107143
# Converting GenBank record NODE_344_length_161_cov_149.940476
# Converting GenBank record NODE_345_length_160_cov_308.409639
# Converting GenBank record NODE_346_length_160_cov_133.759036
# Converting GenBank record NODE_347_length_159_cov_132.939024
# Converting GenBank record NODE_348_length_158_cov_302.790123
# Converting GenBank record NODE_349_length_158_cov_144.135802
# Converting GenBank record NODE_350_length_158_cov_106.160494
# Converting GenBank record NODE_351_length_157_cov_453.912500
# Converting GenBank record NODE_352_length_157_cov_135.50000
# Converting GenBank record NODE_353_length_156_cov_138.202532
# Converting GenBank record NODE_354_length_155_cov_1093.987179
# Converting GenBank record NODE_355_length_155_cov_979.115385
# Converting GenBank record NODE_356_length_155_cov_960.512821
# Converting GenBank record NODE_357_length_155_cov_881.884615
# Converting GenBank record NODE_358_length_155_cov_825.320513
# Converting GenBank record NODE_359_length_155_cov_693.602564
# Converting GenBank record NODE_360_length_155_cov_688.51282
# Converting GenBank record NODE_361_length_155_cov_659.128205
# Converting GenBank record NODE_362_length_155_cov_583.115385
# Converting GenBank record NODE_363_length_155_cov_551.230769
# Converting GenBank record NODE_364_length_155_cov_525.205128
# Converting GenBank record NODE_365_length_155_cov_417.500000
# Converting GenBank record NODE_366_length_155_cov_381.833333
# Converting GenBank record NODE_367_length_155_cov_331.358974
# Converting GenBank record NODE_368_length_155_cov_313.102564
# Converting GenBank record NODE_369_length_155_cov_307.512821
# Converting GenBank record NODE_370_length_155_cov_305.858974
# Converting GenBank record NODE_371_length_155_cov_294.653846
# Converting GenBank record NODE_372_length_155_cov_291.38462
# Converting GenBank record NODE_373_length_155_cov_287.576923
# Converting GenBank record NODE_374_length_155_cov_278.166667
# Converting GenBank record NODE_375_length_155_cov_277.525641
# Converting GenBank record NODE_376_length_155_cov_275.756410
# Converting GenBank record NODE_377_length_155_cov_269.871795
# Converting GenBank record NODE_378_length_155_cov_267.782051
# Converting GenBank record NODE_379_length_155_cov_259.653846
# Converting GenBank record NODE_380_length_155_cov_222.38462
# Converting GenBank record NODE_381_length_155_cov_209.858974
# Converting GenBank record NODE_382_length_155_cov_162.948718
# Converting GenBank record NODE_383_length_155_cov_162.641026
# Converting GenBank record NODE_384_length_155_cov_161.961538
# Converting GenBank record NODE_385_length_155_cov_158.961538
# Converting GenBank record NODE_386_length_155_cov_157.602564
# Converting GenBank record NODE_387_length_155_cov_152.76923
# Converting GenBank record NODE_388_length_155_cov_149.141026
# Converting GenBank record NODE_389_length_155_cov_136.666667
# Converting GenBank record NODE_390_length_155_cov_131.923077
# Converting GenBank record NODE_391_length_155_cov_130.500000
# Converting GenBank record NODE_392_length_155_cov_127.474359
# Converting GenBank record NODE_393_length_155_cov_122.653846
# Converting GenBank record NODE_394_length_155_cov_120.0
# Converting GenBank record NODE_395_length_155_cov_116.461538
# Converting GenBank record NODE_396_length_154_cov_183.38961
# Converting GenBank record NODE_397_length_154_cov_154.987013
# Converting GenBank record NODE_398_length_154_cov_98.415584
# Converting GenBank record NODE_399_length_153_cov_323.776316
# Converting GenBank record NODE_400_length_153_cov_306.342105
# Converting GenBank record NODE_401_length_153_cov_164.592105
# Converting GenBank record NODE_402_length_153_cov_160.552632
# Converting GenBank record NODE_403_length_153_cov_154.986842
# Converting GenBank record NODE_404_length_152_cov_290.586667
# Converting GenBank record NODE_405_length_152_cov_281.746667
# Converting GenBank record NODE_406_length_152_cov_148.813333
# Converting GenBank record NODE_407_length_152_cov_134.560000
# Converting GenBank record NODE_408_length_152_cov_134.533333
# Converting GenBank record NODE_409_length_152_cov_98.760000
# Converting GenBank record NODE_410_length_152_cov_5.413333
# Converting GenBank record NODE_411_length_151_cov_312.675676
# Converting GenBank record NODE_412_length_151_cov_115.459459
# Converting GenBank record NODE_413_length_150_cov_333.602740
# Converting GenBank record NODE_414_length_150_cov_171.520548
# Converting GenBank record NODE_415_length_150_cov_141.424658
# Converting GenBank record NODE_416_length_150_cov_127.808219
# Converting GenBank record NODE_417_length_149_cov_270.333333
# Converting GenBank record NODE_418_length_149_cov_227.305556
# Converting GenBank record NODE_419_length_149_cov_139.708333
# Converting GenBank record NODE_420_length_149_cov_119.319444
# Converting GenBank record NODE_421_length_148_cov_252.774648
# Converting GenBank record NODE_422_length_148_cov_116.535211
# Converting GenBank record NODE_423_length_146_cov_295.463768
# Converting GenBank record NODE_424_length_146_cov_136.43478
# Converting GenBank record NODE_425_length_146_cov_120.956522
# Converting GenBank record NODE_426_length_145_cov_1782.794118
# Converting GenBank record NODE_427_length_138_cov_122.786885
# Converting GenBank record NODE_428_length_135_cov_139.189655
# Converting GenBank record NODE_429_length_131_cov_229.685185
# Converting GenBank record NODE_430_length_127_cov_588.480000
# Converting GenBank record NODE_431_length_126_cov_891.387755
# Converting GenBank record NODE_432_length_126_cov_359.102041
# Converting GenBank record NODE_433_length_126_cov_100.857143
# Converting GenBank record NODE_434_length_125_cov_294.20833
# Converting GenBank record NODE_435_length_124_cov_266.595745
# Converting GenBank record NODE_436_length_124_cov_245.0
# Converting GenBank record NODE_437_length_120_cov_362.116279
# Converting GenBank record NODE_438_length_120_cov_132.930233
# Converting GenBank record NODE_439_length_119_cov_420.476190
# Converting GenBank record NODE_440_length_119_cov_153.428571
# Converting GenBank record NODE_441_length_116_cov_115.461538
# Converting GenBank record NODE_442_length_114_cov_377.108108
# Converting GenBank record NODE_443_length_114_cov_111.837838
# Converting GenBank record NODE_444_length_113_cov_1345.666667
# Converting GenBank record NODE_445_length_112_cov_616.200000
# Converting GenBank record NODE_446_length_112_cov_169.142857
# Converting GenBank record NODE_447_length_112_cov_151.85714
# Converting GenBank record NODE_448_length_110_cov_329.181818
# Converting GenBank record NODE_449_length_110_cov_141.757576
# Converting GenBank record NODE_450_length_109_cov_1020.781250
# Converting GenBank record NODE_451_length_107_cov_689.500000
# Converting GenBank record NODE_452_length_107_cov_630.700000
# Converting GenBank record NODE_453_length_105_cov_809.35714
# Converting GenBank record NODE_454_length_105_cov_313.678571
# Converting GenBank record NODE_455_length_104_cov_1367.555556
# Converting GenBank record NODE_456_length_102_cov_539.400000
# Converting GenBank record NODE_457_length_101_cov_143.708333
# Converting GenBank record NODE_458_length_101_cov_139.375000
# Converting GenBank record NODE_459_length_101_cov_126.416667
# Converting GenBank record NODE_460_length_98_cov_744.428571
# Converting GenBank record NODE_461_length_98_cov_286.619048
# Converting GenBank record NODE_462_length_98_cov_152.857143
# Converting GenBank record NODE_463_length_96_cov_1468.263158
# Converting GenBank record NODE_464_length_95_cov_275.277778
# Converting GenBank record NODE_465_length_94_cov_211.823529
# Converting GenBank record NODE_466_length_94_cov_110.647059
# Converting GenBank record NODE_467_length_94_cov_100.470588
# Converting GenBank record NODE_468_length_93_cov_359.62500
# Converting GenBank record NODE_469_length_93_cov_94.0
# Converting GenBank record NODE_470_length_92_cov_1698.800000
# Converting GenBank record NODE_471_length_92_cov_292.733333
# Converting GenBank record NODE_472_length_92_cov_131.666667
# Converting GenBank record NODE_473_length_91_cov_981.214286
# Converting GenBank record NODE_474_length_91_cov_232.71429
# Converting GenBank record NODE_475_length_91_cov_130.71429
# Converting GenBank record NODE_476_length_89_cov_119.333333
# Converting GenBank record NODE_477_length_89_cov_115.833333
# Converting GenBank record NODE_478_length_87_cov_121.300000
# Converting GenBank record NODE_479_length_87_cov_114.300000
# Converting GenBank record NODE_480_length_86_cov_244.222222
# Converting GenBank record NODE_481_length_86_cov_155.888889
# Converting GenBank record NODE_482_length_86_cov_155.888889
# Converting GenBank record NODE_483_length_86_cov_123.666667
# Converting GenBank record NODE_484_length_85_cov_156.750000
# Converting GenBank record NODE_485_length_85_cov_146.750000
# Converting GenBank record NODE_486_length_85_cov_129.500000
# Converting GenBank record NODE_487_length_84_cov_294.0
# Converting GenBank record NODE_488_length_82_cov_683.800000
# Converting GenBank record NODE_489_length_82_cov_344.800000
# Converting GenBank record NODE_490_length_81_cov_522.750000
# Converting GenBank record NODE_491_length_81_cov_489.250000
# Converting GenBank record NODE_492_length_81_cov_446.0
# Converting GenBank record NODE_493_length_81_cov_305.500000
# Converting GenBank record NODE_494_length_81_cov_275.0
# Converting GenBank record NODE_495_length_81_cov_271.0
# Converting GenBank record NODE_496_length_81_cov_246.0
# Converting GenBank record NODE_497_length_80_cov_1341.333333
# Converting GenBank record NODE_498_length_80_cov_284.333333
# Converting GenBank record NODE_499_length_80_cov_253.333333
# Converting GenBank record NODE_500_length_80_cov_171.333333
# Converting GenBank record NODE_501_length_80_cov_153.666667
# Converting GenBank record NODE_502_length_79_cov_1620.500000
# Converting GenBank record NODE_503_length_79_cov_826.0
# Converting GenBank record NODE_504_length_79_cov_287.500000
# Converting GenBank record NODE_505_length_79_cov_135.500000
# Converting GenBank record NODE_506_length_79_cov_114.500000
# Converting GenBank record NODE_507_length_78_cov_267359.0
# Converting GenBank record NODE_508_length_78_cov_10905.0
# Converting GenBank record NODE_509_length_78_cov_839.0
# Converting GenBank record NODE_510_length_78_cov_533.0
# Converting GenBank record NODE_511_length_78_cov_507.0
# Converting GenBank record NODE_512_length_78_cov_500.0
# Converting GenBank record NODE_513_length_78_cov_415.0
# Converting GenBank record NODE_514_length_78_cov_371.0
# Converting GenBank record NODE_515_length_78_cov_317.0
# Converting GenBank record NODE_516_length_78_cov_309.0
# Converting GenBank record NODE_517_length_78_cov_308.0
# Converting GenBank record NODE_518_length_78_cov_299.0
# Converting GenBank record NODE_519_length_78_cov_297.0
# Converting GenBank record NODE_520_length_78_cov_283.0

# %%
# make nucleotide sequence databases

make_blast_db(targetStrainID, folder = 'genomes', db_type = 'nucl')
# Out:
# making blast db with following command line...
# makeblastdb -in genomes/PmegMOA.fna -dbtype nucl
#
#
# Building a new DB, current time: 03/16/2023 09:53:28
# New DB name:   /home/hugo/Desktop/Master/TFM/GitHub Repo/TFM_Hugo-Salas/TFM_Hugo-Salas/3_Draft Construction/genomes/PmegMOA.fna
# New DB title:  genomes/PmegMOA.fna
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/hugo/Desktop/Master/TFM/GitHub Repo/TFM_Hugo-Salas/TFM_Hugo-Salas/3_Draft Construction/genomes/PmegMOA.fna
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 520 sequences in 0.0407109 seconds.

# %%
# perform uni-directional BLASTn hit

genome_blast_res = []
res = run_blastn(referenceStrainID,targetStrainID)
genome_blast_res.append(res)
# Out:
# running blastn with following command line...
# blastn -db genomes/PmegMOA.fna -query nucl/DSM319.fa -out nucl/DSM319_vs_PmegMOA.txt -evalue 0.001 -outfmt 6 -num_threads 1

# %%
#define a function to parse through the nucleotide BLAST results and form one matrix of all the results

def parse_nucl_blast(infile):
    cols = ['gene', 'subject', 'PID', 'alnLength', 'mismatchCount', 'gapOpenCount', 'queryStart', 'queryEnd', 'subjectStart', 'subjectEnd', 'eVal', 'bitScore']
    data = pd.read_csv(infile, sep = '\t', names = cols)
    data = data[(data['PID'] > 80) & (data['alnLength'] > 0.8 * data['queryEnd'])]
    data2 = data.groupby('gene').first()
    return data2.reset_index()

# %%
'''
# parse the nucleotide blast matrix

na_matrix=pd.DataFrame()

for file in genome_blast_res:
    genes =parse_nucl_blast(file)
    name ='.'.join(file.split('_')[-1].split('.')[:-1])
    na_matrix = na_matrix.append(genes[['gene','subject','PID']])
na_matrix = pd.pivot_table(na_matrix, index='gene', columns='subject',values='PID')

na_matrix.head()
'''
# Out:
# "\n# parse the nucleotide blast matrix\n\nna_matrix=pd.DataFrame()\n\nfor file in genome_blast_res:\n    genes =parse_nucl_blast(file)\n    name ='.'.join(file.split('_')[-1].split('.')[:-1])\n    na_matrix = na_matrix.append(genes[['gene','subject','PID']])\nna_matrix = pd.pivot_table(na_matrix, index='gene', columns='subject',values='PID')\n\nna_matrix.head()\n"

# %%
# parse the nucleotide blast matrixna_matrix = pd.DataFrame()

na_matrix=pd.DataFrame()
file = 'nucl/DSM319_vs_PmegMOA.txt'

genes = parse_nucl_blast(file)
name = '.'.join(file.split('_')[-1].split('.')[:-1])
na_matrix = na_matrix.append(genes[['gene','subject','PID']])

na_matrix = pd.pivot_table(na_matrix, index = 'gene', values = 'PID')
# Out:
# /tmp/ipykernel_5719/1292244146.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   na_matrix = na_matrix.append(genes[['gene','subject','PID']])

# %%
na_matrix.head()
# Out:
#                 PID
# gene
# BMD_RS00005  80.105
# BMD_RS00010  80.299
# BMD_RS00065  83.734
# BMD_RS00085  80.426
# BMD_RS00240  82.126

# %% [markdown]
# ### Examine unnannotated open reading frames
# We compare the results from BLASTp and BLASTn and record any inconsistencies between the two matrices due to missing annotation. This result is then saved to guide future manual curation.

# %%
# define a function to extract the sequence from fna file 

def extract_seq(g, contig, start, end):
    from Bio import SeqIO
    handle = open(g)
    records = SeqIO.parse(handle, "fasta")
    
    for record in records:
        if record.name == contig:
            if end > start:
                section = record[start:end]
            else:
                section = record[end-1:start+1].reverse_complement()
                
            seq = str(section.seq)
    return seq

# %%
#Define updated matrices that will include genes based on sequence evidence that were missing due to lack of annotation

ortho_matrix_w_unannotated = ortho_matrix.copy()
geneIDs_matrix_w_unannotated = geneIDs_matrix.copy()

# %%
#Define matrix of the BLASTn results for all the pertinent model genes

nonModelGenes=[]
for g in na_matrix.index:
    if g not in listGeneIDs:
        nonModelGenes.append(g)

na_model_genes=na_matrix.drop(nonModelGenes)

# %%
na_model_genes
# Out:
#                 PID
# gene
# BMD_RS00065  83.734
# BMD_RS00325  83.430
# BMD_RS00440  83.203
# BMD_RS00450  82.888
# BMD_RS00765  88.073
# ...             ...
# BMD_RS25170  81.949
# BMD_RS25260  82.609
# BMD_RS25265  85.674
# BMD_RS25275  81.882
# BMD_RS25525  87.257
#
# [93 rows x 1 columns]

# %%
#For each strain in the ortho_matrix, identify genes that meet threshold of SEQ similarity, but missing from
#annotated ORFS. Additionally, look at the sequence to ensure that these cases do not have early stop codons indicating
#nonfunctional even if the NA seqs meet the threshold

pseudogenes = {}

for c in ortho_matrix.columns:
    
    orfs = ortho_matrix[c]
    genes = na_model_genes['PID']
    # All the Model Genes that met the BLASTp Requirements
    orfs2 = orfs[orfs == 1].index.tolist()
    # All the Model Genes based off of BLASTn similarity above threshold of 80
    genes2 = genes[genes>=80].index.tolist()
    # By Definition find the genes that pass sequence threshold but were NOT in annotated ORFs:
    unannotated = set(genes2) -set(orfs2)
    
    # Obtain sequences of this list to check for premature stop codons:
    data = 'nucl/DSM319_vs_%s.txt'%c
    cols = ['gene', 'subject', 'PID', 'alnLength', 'mismatchCount', 'gapOpenCount', 'queryStart', 'queryEnd', 'subjectStart', 'subjectEnd', 'eVal', 'bitScore']
    data = pd.read_csv(data, sep='\t', names=cols)
    #
    pseudogenes[c] = {}
    unannotated_data = data[data['gene'].isin(list(unannotated))]
    for i in unannotated_data.index:
        gene = data.loc[i,'gene']
        contig = data.loc[i,'subject'] 
        start = data.loc[i,'subjectStart']
        end = data.loc[i,'subjectEnd']
        seq = extract_seq('genomes/%s.fna'%c,contig, start, end)
        # check for early stop codons - these are likely nonfunctional and shouldn't be included
        if '*' in seq:
            print (seq)
            pseudogenes[c][gene]=seq
            # Remove the gene from list of unannotated genes
            unannotated-set([gene])
            
    print (c, unannotated)
    
    # For pertinent genes, retain those based off of nucleotide similarity within the orthology matrix and geneIDs matrix
    ortho_matrix_w_unannotated.loc[unannotated,c]=1
    for g in unannotated:
        geneIDs_matrix_w_unannotated.loc[g,c] = '%s_ortholog'%g
# Out:
# PmegMOA set()
# /tmp/ipykernel_5719/1993328310.py:41: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   ortho_matrix_w_unannotated.loc[unannotated,c]=1

# %%
#Save the Presence/Absence Matrix and geneIDs Matrix for future use

ortho_matrix_w_unannotated.to_csv('ortho_matrix.csv')
geneIDs_matrix_w_unannotated.to_csv('geneIDs_matrix.csv')

# %% [markdown]
# # Notebook 2: Generate multi-strain models
#
# This notebook follows Notebook 1 in the tutorial, and continues to work on generating multi-strain E.coli models. This notebook utilizes the output of notebook 1 (presence/absence matrix and geneID matrix) to generate draft strain-specific models from the
# reference model. There are two major steps involved:
#
# 1. Deletion of missing genes/reaction from reference model to generate draft models
# 2. Update gene-protein-reaction rule in each model

# %%
#import package needed
import cobra
import pandas as pd
from cobra.io import read_sbml_model
from glob import glob
from cobra.manipulation.delete import delete_model_genes, remove_genes

# %% [markdown]
# ## 1. Deletion of missing genes/reaction from reference model

# %%
#Load the base E. coli reconstruction iML1515

model = read_sbml_model('DSM319_fixedIDs.xml')
model
# Out:
# <Model M_ at 0x7f4db2398370>

# %%
## Load the previously generated homology matrix for E. coli strains of interest
hom_matrix=pd.read_csv('ortho_matrix.csv')
hom_matrix=hom_matrix.set_index('Unnamed: 0')

# %%
hom_matrix
# Out:
#              PmegMOA
# Unnamed: 0
# BMD_RS23170      1.0
# BMD_RS25275      1.0
# BMD_RS08645      1.0
# BMD_RS15095      1.0
# BMD_RS03235      1.0
# ...              ...
# BMD_RS06270      1.0
# BMD_RS17410      0.0
# BMD_RS05375      0.0
# BMD_RS05380      0.0
# BMD_RS04495      0.0
#
# [1121 rows x 1 columns]

# %% [markdown]
# ### Delete missing genes from copies of the iML1515 model
# For each strain, start with the iML1515 model, identify the missing genes from the matrix, and remove them and their associated reactions from the reference model

# %%
#create strain-specific draft models and save them
for strain in hom_matrix.columns:
    
    #Get the list of Gene IDs from the homology matrix dataframe for the current strain without a homolog
    currentStrain = hom_matrix[strain]
    nonHomologous = currentStrain[currentStrain == 0.0]
    nonHomologous = nonHomologous.index.tolist()
    '''
    #s0001 is an artificial gene used in iML1515 for spontaneous reactions and as such has no homologs,
    #However, it is retained for these spontaneous reactions to function
    nonHomologous.remove('s0001')
    '''
    #Define a list of Gene objects from the base reconstruction to be deleted from the current strain
    toDelete = []
    for gene in nonHomologous:
        toDelete.append(model.genes.get_by_id(gene))

    #Establish a model copy and use the COBRApy function to remove the appropriate content and save this model
    modelCopy = model.copy()
    remove_genes(modelCopy, toDelete, remove_reactions = True)
    modelCopy.id = str(strain)
    cobra.io.json.save_json_model(modelCopy, str('Models/'+strain+'.json'), pretty = False)
# Out:
# Read LP format model from file /tmp/tmp_7x2h_eo.lp
# Reading time = 0.01 seconds
# : 1349 rows, 3418 columns, 14542 nonzeros
# /home/hugo/anaconda3/lib/python3.8/site-packages/cobra/core/group.py:147: UserWarning: need to pass in a list
#   warn("need to pass in a list")

# %% [markdown]
# ## 2. Update Model Gene Product Rules

# %%
#load the geneID matrix from the notebook1 

models=glob('%s/*.json'%'Models')
geneIDs_matrix=pd.read_csv('geneIDs_matrix.csv')
geneIDs_matrix=geneIDs_matrix.set_index('Unnamed: 0')
geneIDs_matrix
# Out:
#                                              PmegMOA
# Unnamed: 0
# BMD_RS23170   NODE_16_length_54124_cov_156.061039_25
# BMD_RS25275    NODE_9_length_68904_cov_166.400657_69
# BMD_RS08645    NODE_41_length_28144_cov_287.375387_5
# BMD_RS15095    NODE_41_length_28144_cov_287.375387_5
# BMD_RS03235   NODE_47_length_25520_cov_164.773651_18
# ...                                              ...
# BMD_RS06270  NODE_1_length_132867_cov_126.236720_117
# BMD_RS17410    NODE_154_length_6180_cov_107.793216_1
# BMD_RS05375                                     None
# BMD_RS05380                                     None
# BMD_RS04495    NODE_136_length_8236_cov_295.529477_4
#
# [1121 rows x 1 columns]

# %%
#Utilize the geneIDs matrix to update the GPRs in each of the strain-specific models with the proper gene ID
# OG
from cobra.manipulation.modify import rename_genes

for mod in models:
    model=cobra.io.load_json_model(mod)
    for column in geneIDs_matrix.columns:
        if column in mod:
            currentStrain=column
    
    IDMapping=geneIDs_matrix[currentStrain].to_dict()
    IDMappingParsed = {k:v for k,v in IDMapping.items() if v != 'None'}
    
    rename_genes(model,IDMappingParsed)
    cobra.io.json.save_json_model(model,mod, pretty=False)

# %%
#Utilize the geneIDs matrix to update the GPRs in each of the strain-specific models with the proper gene ID

from cobra.manipulation.modify import rename_genes

for mod in models:
    model=cobra.io.load_json_model(mod)
    for column in geneIDs_matrix.columns:
        if column in mod:
            currentStrain=column
    
    IDMapping=geneIDs_matrix[currentStrain].to_dict()
    IDMappingParsed = {v:k for k,v in IDMapping.items() if v != 'None'}
    
    rename_genes(model,IDMappingParsed)
    cobra.io.json.save_json_model(model,mod, pretty=False)

# %%
# gather the general information on the draft models
for strain in hom_matrix.columns:
    model=cobra.io.load_json_model(str('Models/'+strain+'.json'))
    print (model.id,'Number of Model Genes:',len(model.genes),'Number of Model Reactions:',len(model.reactions))
# Out:
# PmegMOA Number of Model Genes: 422 Number of Model Reactions: 1082

# %%
from cobra.io import load_json_model, write_sbml_model
final_mod = load_json_model('Models/PmegMOA.json')
write_sbml_model(final_mod, 'Models/PmegMOA.xml')

# %%
# Save it as an .xlsx file

import importExcelModel
importExcelModel.cobrapy_to_excel(final_mod, 'Models/PmegMOA.xlsx')
